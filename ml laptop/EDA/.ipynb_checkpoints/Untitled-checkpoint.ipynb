# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("C:\\Users\\goaud\\Desktop\\ml laptop\\Data\\laptop_trendyol_data.xlsx")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1968 entries, 0 to 1967
# Data columns (total 67 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ArttÄ±rÄ±labilir Azami Bellek    8 non-null      object
#  1   Arttırılabilir Azami Bellek      135 non-null    object
#  2   BaÄŸlantÄ±lar                    17 non-null     object
#  3   Bağlantılar                      1282 non-null   object
#  4   Bağlantılar (İkincil)            18 non-null     object
#  5   Cihaz AÄŸÄ±rlÄ±ÄŸÄ±              31 non-null     object
#  6   Cihaz Ağırlığı                   1673 non-null   object
#  7   Dokunmatik Ekran                 1703 non-null   object
#  8   Ekran Boyutu                     1704 non-null   object
#  9   Ekran KartÄ±                     31 non-null     object
#  10  Ekran KartÄ± Bellek Tipi         31 non-null     object
#  11  Ekran KartÄ± HafÄ±zasÄ±          31 non-null     object
# ...

# %%
data = data.drop(['ArttÄ±rÄ±labilir Azami Bellek', 'BaÄŸlantÄ±lar','Cihaz AÄŸÄ±rlÄ±ÄŸÄ±','Ekran KartÄ±','Ekran KartÄ± Bellek Tipi','Ekran KartÄ± HafÄ±zasÄ±','Ekran KartÄ± Tipi','Ekran Yenileme HÄ±zÄ±','Garanti SÃ¼resi','KullanÄ±m AmacÄ±','Maksimum Ä°ÅŸlemci HÄ±zÄ± (GHz)','Okula DÃ¶nÃ¼ÅŸ','Optik SÃ¼rÃ¼cÃ¼ Tipi','Ram (Sistem BelleÄŸi)','Ram (Sistem BelleÄŸi) Tipi','Temel Ä°ÅŸlemci HÄ±zÄ± (GHz)','Ã‡Ã¶zÃ¼nÃ¼rlÃ¼k','Ã‡Ã¶zÃ¼nÃ¼rlÃ¼k StandartÄ±','Ä°ÅŸlemci Modeli','Ä°ÅŸlemci Nesli','Ä°ÅŸlemci Tipi','Ä°ÅŸlemci Ã‡ekirdek SayÄ±sÄ±','Ä°ÅŸletim Sistemi','ÅžarjlÄ± KullanÄ±m SÃ¼resi'],axis = 1)

# %%
data.head(10)
# Out:
#   Arttırılabilir Azami Bellek             Bağlantılar Bağlantılar (İkincil)  \
# 0                         NaN  USB - Bluetooth - HDMI                   NaN
# 1                         NaN                     NaN                   NaN
# 2                         NaN                     NaN                   NaN
# 3                         NaN                     NaN                   NaN
# 4                         NaN  USB - Bluetooth - HDMI                   NaN
# 5                         NaN                     NaN                   NaN
# 6                         NaN        Bluetooth - HDMI                   NaN
# 7                         NaN                     NaN                   NaN
# 8                         NaN                     NaN                   NaN
# 9                         NaN                     NaN                   NaN
#
#   Cihaz Ağırlığı Dokunmatik Ekran Ekran Boyutu          Ekran Kartı  \
# ...

# %%
plt.figure(figsize=(16,16))
plt.subplot(2,1,1)
sns.countplot(x='brand',data = data,order = data['brand'].value_counts().index)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(16,16))
plt.subplot(2,1,1)
sns.countplot(x='İşletim Sistemi',data = data,order = data['İşletim Sistemi'].value_counts().index)
plt.xticks(rotation = 90)
plt.show()
